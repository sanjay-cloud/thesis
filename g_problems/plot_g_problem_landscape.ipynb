# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize
from numpy.random import rand

# %%
from g_problem import GProblem
import g01 
import g02 
import g03 
import g04 
import g05 
import g06
import g07 
import g08
import g09 
import g10 
import g11

# %%
g01.problem().plot_landscape(False)

# %%
g01.problem().plot_landscape()

# %%
g02.problem().plot_landscape(False)

# %%
g02.problem().plot_landscape()

# %%
g03.problem().plot_landscape(False)

# %%
g03.problem().plot_landscape()

# %%
g04.problem().plot_landscape(False)

# %%
g04.problem().plot_landscape()

# %%
g05.problem().plot_landscape(False)

# %%
g05.problem().plot_landscape()

# %%
g06.problem().plot_landscape()

# %%
g06.problem().plot_landscape(False)

# %%
g07.problem().plot_landscape(False)

# %%
g07.problem().plot_landscape()

# %%
g08.problem().plot_landscape(True)
# Out:
# d:\thesis\mix-int-cmaes\optuna-cmaeswm\g_problems\g08.py:15: RuntimeWarning: invalid value encountered in scalar divide
#   return - (np.sin(2 * np.pi * x[0])**3 * np.sin(2 * np.pi * x[1])) / (x[0]**3 * (x[0] + x[1]))

# %%
g08.problem().plot_landscape(False)

# %%
g09.problem().plot_landscape(False)

# %%
g09.problem().plot_landscape()

# %%
g10.problem().plot_landscape(False)

# %%
g10.problem().plot_landscape()

# %%
g11.problem().plot_landscape(True)

# %%
g11.problem().plot_landscape(False)
